# %%
# Import Libraries

import pandas as pd
import numpy as np
import os

# %%
# Import ords_prods_merge

path = r'C:\Users\lefev\Documents\Data Analytics Course\Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_prods_merge_updated.pkl'))

# %%
# Check the shape 

ords_prods_merge.shape
# Out:
# (32404859, 19)

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0     3355525         2   202279    prior             3                   5
# 1     3355525         2   202279    prior             3                   5
# 2     3355525         2   202279    prior             3                   5
# 3     3355525         2   202279    prior             3                   5
# 4     3355525         2   202279    prior             3                   5
#
#    order_time  days_since_prior_order  product_id  add_to_cart_order  \
# 0           9                     8.0     33120.0                1.0
# 1           9                     8.0     28985.0                2.0
# 2           9                     8.0      9327.0                3.0
# 3           9                     8.0     45918.0                4.0
# 4           9                     8.0     30035.0                5.0
#
#    reordered           product_name  aisle_id  department_id  prices _merge  \
# 0        1.0     Organic Egg Whites        86             16    11.3   both
# 1        1.0  Michigan Organic Kale        83              4    13.4   both
# 2        0.0          Garlic Powder       104             13     3.6   both
# 3        1.0         Coconut Butter        19             13     8.4   both
# 4        0.0      Natural Sweetener        17             13    13.7   both
#
#      price_range_loc         busiest_days busiest_period_of_day
# 0  Mid-range product  Regularly busy days           Most orders
# 1  Mid-range product  Regularly busy days           Most orders
# 2  Low-range product  Regularly busy days           Most orders
# 3  Mid-range product  Regularly busy days           Most orders
# 4  Mid-range product  Regularly busy days           Most orders

# %%
# Create a smaller subset to help with memory

df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 19)

# %%
df.groupby('product_name')

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.632732
# 2                18.463588
# 3                17.393945
# 4                17.987803
# 5                14.406216
# 6                16.521620
# 7                17.414215
# 8                16.041537
# 9                16.085128
# 10               21.290293
# 11               16.496514
# 12               16.089872
# 13               16.787172
# 14               16.900691
# 15               16.446757
# 16               17.816166
# 17               16.075612
# 18               19.197182
# 19               17.406295
# 20               16.678997
# 21               23.262204

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.632732   1  99
# 2                18.463588   1  97
# 3                17.393945   1  99
# 4                17.987803   1  99
# 5                14.406216   1  99
# 6                16.521620   1  99
# 7                17.414215   1  99
# 8                16.041537   1  96
# 9                16.085128   1  99
# 10               21.290293   1  99
# 11               16.496514   1  99
# 12               16.089872   1  99
# 13               16.787172   1  99
# 14               16.900691   1  99
# 15               16.446757   1  99
# 16               17.816166   1  99
# 17               16.075612   1  99
# 18               19.197182   1  99
# 19               17.406295   1  99
# 20               16.678997   1  99
# 21               23.262204   1  98

# %%
# Create a max order column

ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\lefev\AppData\Local\Temp\ipykernel_29100\4155048890.py:3: FutureWarning: The provided callable <function max at 0x000001169F946160> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0      3355525         2   202279    prior             3                   5
# 1      3355525         2   202279    prior             3                   5
# 2      3355525         2   202279    prior             3                   5
# 3      3355525         2   202279    prior             3                   5
# 4      3355525         2   202279    prior             3                   5
# 5      3355525         2   202279    prior             3                   5
# 6      3355525         2   202279    prior             3                   5
# 7      3355525         2   202279    prior             3                   5
# 8      3355525         2   202279    prior             3                   5
# 9      3417191         3   205970    prior            16                   5
# 10     3417191         3   205970    prior            16                   5
# 11     3417191         3   205970    prior            16                   5
# 12     3417191         3   205970    prior            16                   5
# 13     3417191         3   205970    prior            16                   5
# 14     3417191         3   205970    prior            16                   5
#
#     order_time  days_since_prior_order  product_id  add_to_cart_order  \
# 0            9                     8.0     33120.0                1.0
# 1            9                     8.0     28985.0                2.0
# 2            9                     8.0      9327.0                3.0
# 3            9                     8.0     45918.0                4.0
# 4            9                     8.0     30035.0                5.0
# 5            9                     8.0     17794.0                6.0
# 6            9                     8.0     40141.0                7.0
# 7            9                     8.0      1819.0                8.0
# 8            9                     8.0     43668.0                9.0
# 9           17                    12.0     33754.0                1.0
# 10          17                    12.0     24838.0                2.0
# 11          17                    12.0     17704.0                3.0
# 12          17                    12.0     21903.0                4.0
# 13          17                    12.0     17668.0                5.0
# 14          17                    12.0     46667.0                6.0
#
#     reordered                                       product_name  aisle_id  \
# 0         1.0                                 Organic Egg Whites        86
# 1         1.0                              Michigan Organic Kale        83
# 2         0.0                                      Garlic Powder       104
# 3         1.0                                     Coconut Butter        19
# 4         0.0                                  Natural Sweetener        17
# 5         1.0                                            Carrots        83
# 6         1.0                   Original Unflavored Gelatine Mix       105
# 7         1.0           All Natural No Stir Creamy Almond Butter        88
# 8         0.0                            Classic Blend Cole Slaw       123
# 9         1.0  Total 2% with Strawberry Lowfat Greek Strained...       120
# 10        1.0                             Unsweetened Almondmilk        91
# 11        1.0                                             Lemons       123
# 12        1.0                               Organic Baby Spinach       123
# 13        1.0    Unsweetened Chocolate Almond Breeze Almond Milk        91
# 14        1.0                                Organic Ginger Root        83
#
#     department_id  prices _merge    price_range_loc         busiest_days  \
# 0              16    11.3   both  Mid-range product  Regularly busy days
# 1               4    13.4   both  Mid-range product  Regularly busy days
# 2              13     3.6   both  Low-range product  Regularly busy days
# 3              13     8.4   both  Mid-range product  Regularly busy days
# 4              13    13.7   both  Mid-range product  Regularly busy days
# 5               4    10.7   both  Mid-range product  Regularly busy days
# 6              13    11.5   both  Mid-range product  Regularly busy days
# 7              13    11.5   both  Mid-range product  Regularly busy days
# 8               4     7.5   both  Mid-range product  Regularly busy days
# 9              16    11.8   both  Mid-range product  Regularly busy days
# 10             16     5.3   both  Mid-range product  Regularly busy days
# 11              4    10.0   both  Mid-range product  Regularly busy days
# 12              4     8.2   both  Mid-range product  Regularly busy days
# 13             16     6.6   both  Mid-range product  Regularly busy days
# 14              4     6.9   both  Mid-range product  Regularly busy days
#
#    busiest_period_of_day  max_order
# 0            Most orders          8
# 1            Most orders          8
# 2            Most orders          8
# 3            Most orders          8
# 4            Most orders          8
# 5            Most orders          8
# 6            Most orders          8
# 7            Most orders          8
# 8            Most orders          8
# 9            Most orders         25
# 10           Most orders         25
# 11           Most orders         25
# 12           Most orders         25
# 13           Most orders         25
# 14           Most orders         25

# %%
ords_prods_merge[ords_prods_merge['user_id'] == 1]
# Out:
#           Unnamed: 0  order_id  user_id eval_set  order_number  \
# 4085667            4    431534        1    prior             5
# 4085668            4    431534        1    prior             5
# 4085669            4    431534        1    prior             5
# 4085670            4    431534        1    prior             5
# 4085671            4    431534        1    prior             5
# 4085672            4    431534        1    prior             5
# 4085673            4    431534        1    prior             5
# 4085674            4    431534        1    prior             5
# 4484016            2    473747        1    prior             3
# 4484017            2    473747        1    prior             3
# 4484018            2    473747        1    prior             3
# 4484019            2    473747        1    prior             3
# 4484020            2    473747        1    prior             3
# 5208174            6    550135        1    prior             7
# 5208175            6    550135        1    prior             7
# 5208176            6    550135        1    prior             7
# 5208177            6    550135        1    prior             7
# 5208178            6    550135        1    prior             7
# 21356576           3   2254736        1    prior             4
# 21356577           3   2254736        1    prior             4
# 21356578           3   2254736        1    prior             4
# 21356579           3   2254736        1    prior             4
# 21356580           3   2254736        1    prior             4
# 21740575           8   2295261        1    prior             9
# 21740576           8   2295261        1    prior             9
# 21740577           8   2295261        1    prior             9
# 21740578           8   2295261        1    prior             9
# 21740579           8   2295261        1    prior             9
# 21740580           8   2295261        1    prior             9
# 22722017           1   2398795        1    prior             2
# 22722018           1   2398795        1    prior             2
# 22722019           1   2398795        1    prior             2
# 22722020           1   2398795        1    prior             2
# 22722021           1   2398795        1    prior             2
# 22722022           1   2398795        1    prior             2
# 24054778           0   2539329        1    prior             1
# 24054779           0   2539329        1    prior             1
# 24054780           0   2539329        1    prior             1
# 24054781           0   2539329        1    prior             1
# 24054782           0   2539329        1    prior             1
# 24159284           9   2550362        1    prior            10
# 24159285           9   2550362        1    prior            10
# 24159286           9   2550362        1    prior            10
# 24159287           9   2550362        1    prior            10
# 24159288           9   2550362        1    prior            10
# 24159289           9   2550362        1    prior            10
# 24159290           9   2550362        1    prior            10
# 24159291           9   2550362        1    prior            10
# 24159292           9   2550362        1    prior            10
# 29447947           7   3108588        1    prior             8
# 29447948           7   3108588        1    prior             8
# 29447949           7   3108588        1    prior             8
# 29447950           7   3108588        1    prior             8
# 29447951           7   3108588        1    prior             8
# 29447952           7   3108588        1    prior             8
# 31897905           5   3367565        1    prior             6
# 31897906           5   3367565        1    prior             6
# 31897907           5   3367565        1    prior             6
# 31897908           5   3367565        1    prior             6
#
#           orders_day_of_week  order_time  days_since_prior_order  product_id  \
# 4085667                    4          15                    28.0       196.0
# 4085668                    4          15                    28.0     12427.0
# 4085669                    4          15                    28.0     10258.0
# 4085670                    4          15                    28.0     25133.0
# 4085671                    4          15                    28.0     10326.0
# 4085672                    4          15                    28.0     17122.0
# 4085673                    4          15                    28.0     41787.0
# 4085674                    4          15                    28.0     13176.0
# 4484016                    3          12                    21.0       196.0
# 4484017                    3          12                    21.0     12427.0
# 4484018                    3          12                    21.0     10258.0
# 4484019                    3          12                    21.0     25133.0
# 4484020                    3          12                    21.0     30450.0
# 5208174                    1           9                    20.0       196.0
# 5208175                    1           9                    20.0     10258.0
# 5208176                    1           9                    20.0     12427.0
# 5208177                    1           9                    20.0     25133.0
# 5208178                    1           9                    20.0     13032.0
# 21356576                   4           7                    29.0       196.0
# 21356577                   4           7                    29.0     12427.0
# 21356578                   4           7                    29.0     10258.0
# 21356579                   4           7                    29.0     25133.0
# 21356580                   4           7                    29.0     26405.0
# 21740575                   1          16                     0.0     49235.0
# 21740576                   1          16                     0.0     46149.0
# 21740577                   1          16                     0.0     25133.0
# 21740578                   1          16                     0.0       196.0
# 21740579                   1          16                     0.0     10258.0
# 21740580                   1          16                     0.0     12427.0
# 22722017                   3           7                    15.0       196.0
# 22722018                   3           7                    15.0     10258.0
# 22722019                   3           7                    15.0     12427.0
# 22722020                   3           7                    15.0     13176.0
# 22722021                   3           7                    15.0     26088.0
# 22722022                   3           7                    15.0     13032.0
# 24054778                   2           8                     NaN       196.0
# 24054779                   2           8                     NaN     14084.0
# 24054780                   2           8                     NaN     12427.0
# 24054781                   2           8                     NaN     26088.0
# 24054782                   2           8                     NaN     26405.0
# 24159284                   4           8                    30.0       196.0
# 24159285                   4           8                    30.0     46149.0
# 24159286                   4           8                    30.0     39657.0
# 24159287                   4           8                    30.0     38928.0
# 24159288                   4           8                    30.0     25133.0
# 24159289                   4           8                    30.0     10258.0
# 24159290                   4           8                    30.0     35951.0
# 24159291                   4           8                    30.0     13032.0
# 24159292                   4           8                    30.0     12427.0
# 29447947                   1          14                    14.0     12427.0
# 29447948                   1          14                    14.0       196.0
# 29447949                   1          14                    14.0     10258.0
# 29447950                   1          14                    14.0     25133.0
# 29447951                   1          14                    14.0     46149.0
# 29447952                   1          14                    14.0     49235.0
# 31897905                   2           7                    19.0       196.0
# 31897906                   2           7                    19.0     12427.0
# 31897907                   2           7                    19.0     10258.0
# 31897908                   2           7                    19.0     25133.0
#
#           add_to_cart_order  reordered  \
# 4085667                 1.0        1.0
# 4085668                 2.0        1.0
# 4085669                 3.0        1.0
# 4085670                 4.0        1.0
# 4085671                 5.0        0.0
# 4085672                 6.0        0.0
# 4085673                 7.0        0.0
# 4085674                 8.0        1.0
# 4484016                 1.0        1.0
# 4484017                 2.0        1.0
# 4484018                 3.0        1.0
# 4484019                 4.0        0.0
# 4484020                 5.0        0.0
# 5208174                 1.0        1.0
# 5208175                 2.0        1.0
# 5208176                 3.0        1.0
# 5208177                 4.0        1.0
# 5208178                 5.0        1.0
# 21356576                1.0        1.0
# 21356577                2.0        1.0
# 21356578                3.0        1.0
# 21356579                4.0        1.0
# 21356580                5.0        1.0
# 21740575                1.0        1.0
# 21740576                2.0        1.0
# 21740577                3.0        1.0
# 21740578                4.0        1.0
# 21740579                5.0        1.0
# 21740580                6.0        1.0
# 22722017                1.0        1.0
# 22722018                2.0        0.0
# 22722019                3.0        1.0
# 22722020                4.0        0.0
# 22722021                5.0        1.0
# 22722022                6.0        0.0
# 24054778                1.0        0.0
# 24054779                2.0        0.0
# 24054780                3.0        0.0
# 24054781                4.0        0.0
# 24054782                5.0        0.0
# 24159284                1.0        1.0
# 24159285                2.0        1.0
# 24159286                3.0        0.0
# 24159287                4.0        0.0
# 24159288                5.0        1.0
# 24159289                6.0        1.0
# 24159290                7.0        0.0
# 24159291                8.0        1.0
# 24159292                9.0        1.0
# 29447947                1.0        1.0
# 29447948                2.0        1.0
# 29447949                3.0        1.0
# 29447950                4.0        1.0
# 29447951                5.0        0.0
# 29447952                6.0        0.0
# 31897905                1.0        1.0
# 31897906                2.0        1.0
# 31897907                3.0        1.0
# 31897908                4.0        1.0
#
#                                      product_name  aisle_id  department_id  \
# 4085667                                      Soda        77              7
# 4085668                       Original Beef Jerky        23             19
# 4085669                                Pistachios       117             19
# 4085670                     Organic String Cheese        21             16
# 4085671                       Organic Fuji Apples        24              4
# 4085672                         Honeycrisp Apples        24              4
# 4085673                            Bartlett Pears        24              4
# 4085674                    Bag of Organic Bananas        24              4
# 4484016                                      Soda        77              7
# 4484017                       Original Beef Jerky        23             19
# 4484018                                Pistachios       117             19
# 4484019                     Organic String Cheese        21             16
# 4484020                      Creamy Almond Butter        88             13
# 5208174                                      Soda        77              7
# 5208175                                Pistachios       117             19
# 5208176                       Original Beef Jerky        23             19
# 5208177                     Organic String Cheese        21             16
# 5208178                     Cinnamon Toast Crunch       121             14
# 21356576                                     Soda        77              7
# 21356577                      Original Beef Jerky        23             19
# 21356578                               Pistachios       117             19
# 21356579                    Organic String Cheese        21             16
# 21356580         XL Pick-A-Size Paper Towel Rolls        54             17
# 21740575                      Organic Half & Half        53             16
# 21740576                        Zero Calorie Cola        77              7
# 21740577                    Organic String Cheese        21             16
# 21740578                                     Soda        77              7
# 21740579                               Pistachios       117             19
# 21740580                      Original Beef Jerky        23             19
# 22722017                                     Soda        77              7
# 22722018                               Pistachios       117             19
# 22722019                      Original Beef Jerky        23             19
# 22722020                   Bag of Organic Bananas        24              4
# 22722021               Aged White Cheddar Popcorn        23             19
# 22722022                    Cinnamon Toast Crunch       121             14
# 24054778                                     Soda        77              7
# 24054779  Organic Unsweetened Vanilla Almond Milk        91             16
# 24054780                      Original Beef Jerky        23             19
# 24054781               Aged White Cheddar Popcorn        23             19
# 24054782         XL Pick-A-Size Paper Towel Rolls        54             17
# 24159284                                     Soda        77              7
# 24159285                        Zero Calorie Cola        77              7
# 24159286                   Milk Chocolate Almonds        45             19
# 24159287                 0% Greek Strained Yogurt       120             16
# 24159288                    Organic String Cheese        21             16
# 24159289                               Pistachios       117             19
# 24159290          Organic Unsweetened Almond Milk        91             16
# 24159291                    Cinnamon Toast Crunch       121             14
# 24159292                      Original Beef Jerky        23             19
# 29447947                      Original Beef Jerky        23             19
# 29447948                                     Soda        77              7
# 29447949                               Pistachios       117             19
# 29447950                    Organic String Cheese        21             16
# 29447951                        Zero Calorie Cola        77              7
# 29447952                      Organic Half & Half        53             16
# 31897905                                     Soda        77              7
# 31897906                      Original Beef Jerky        23             19
# 31897907                               Pistachios       117             19
# 31897908                    Organic String Cheese        21             16
#
#           prices _merge    price_range_loc         busiest_days  \
# 4085667      9.0   both  Mid-range product      Least busy days
# 4085668      4.4   both  Low-range product      Least busy days
# 4085669      3.0   both  Low-range product      Least busy days
# 4085670      8.6   both  Mid-range product      Least busy days
# 4085671      2.7   both  Low-range product      Least busy days
# 4085672     14.0   both  Mid-range product      Least busy days
# 4085673      5.0   both  Low-range product      Least busy days
# 4085674     10.3   both  Mid-range product      Least busy days
# 4484016      9.0   both  Mid-range product      Least busy days
# 4484017      4.4   both  Low-range product      Least busy days
# 4484018      3.0   both  Low-range product      Least busy days
# 4484019      8.6   both  Mid-range product      Least busy days
# 4484020      3.2   both  Low-range product      Least busy days
# 5208174      9.0   both  Mid-range product         Busiest days
# 5208175      3.0   both  Low-range product         Busiest days
# 5208176      4.4   both  Low-range product         Busiest days
# 5208177      8.6   both  Mid-range product         Busiest days
# 5208178      4.0   both  Low-range product         Busiest days
# 21356576     9.0   both  Mid-range product      Least busy days
# 21356577     4.4   both  Low-range product      Least busy days
# 21356578     3.0   both  Low-range product      Least busy days
# 21356579     8.6   both  Mid-range product      Least busy days
# 21356580     1.0   both  Low-range product      Least busy days
# 21740575     1.8   both  Low-range product         Busiest days
# 21740576    13.4   both  Mid-range product         Busiest days
# 21740577     8.6   both  Mid-range product         Busiest days
# 21740578     9.0   both  Mid-range product         Busiest days
# 21740579     3.0   both  Low-range product         Busiest days
# 21740580     4.4   both  Low-range product         Busiest days
# 22722017     9.0   both  Mid-range product      Least busy days
# 22722018     3.0   both  Low-range product      Least busy days
# 22722019     4.4   both  Low-range product      Least busy days
# 22722020    10.3   both  Mid-range product      Least busy days
# 22722021     4.7   both  Low-range product      Least busy days
# 22722022     4.0   both  Low-range product      Least busy days
# 24054778     9.0   both  Mid-range product  Regularly busy days
# 24054779    12.5   both  Mid-range product  Regularly busy days
# 24054780     4.4   both  Low-range product  Regularly busy days
# 24054781     4.7   both  Low-range product  Regularly busy days
# 24054782     1.0   both  Low-range product  Regularly busy days
# 24159284     9.0   both  Mid-range product      Least busy days
# 24159285    13.4   both  Mid-range product      Least busy days
# 24159286     6.8   both  Mid-range product      Least busy days
# 24159287    12.6   both  Mid-range product      Least busy days
# 24159288     8.6   both  Mid-range product      Least busy days
# 24159289     3.0   both  Low-range product      Least busy days
# 24159290     1.3   both  Low-range product      Least busy days
# 24159291     4.0   both  Low-range product      Least busy days
# 24159292     4.4   both  Low-range product      Least busy days
# 29447947     4.4   both  Low-range product         Busiest days
# 29447948     9.0   both  Mid-range product         Busiest days
# 29447949     3.0   both  Low-range product         Busiest days
# 29447950     8.6   both  Mid-range product         Busiest days
# 29447951    13.4   both  Mid-range product         Busiest days
# 29447952     1.8   both  Low-range product         Busiest days
# 31897905     9.0   both  Mid-range product  Regularly busy days
# 31897906     4.4   both  Low-range product  Regularly busy days
# 31897907     3.0   both  Low-range product  Regularly busy days
# 31897908     8.6   both  Mid-range product  Regularly busy days
#
#          busiest_period_of_day  max_order
# 4085667            Most orders         10
# 4085668            Most orders         10
# 4085669            Most orders         10
# 4085670            Most orders         10
# 4085671            Most orders         10
# 4085672            Most orders         10
# 4085673            Most orders         10
# 4085674            Most orders         10
# 4484016            Most orders         10
# 4484017            Most orders         10
# 4484018            Most orders         10
# 4484019            Most orders         10
# 4484020            Most orders         10
# 5208174            Most orders         10
# 5208175            Most orders         10
# 5208176            Most orders         10
# 5208177            Most orders         10
# 5208178            Most orders         10
# 21356576         Fewest orders         10
# 21356577         Fewest orders         10
# 21356578         Fewest orders         10
# 21356579         Fewest orders         10
# 21356580         Fewest orders         10
# 21740575           Most orders         10
# 21740576           Most orders         10
# 21740577           Most orders         10
# 21740578           Most orders         10
# 21740579           Most orders         10
# 21740580           Most orders         10
# 22722017         Fewest orders         10
# 22722018         Fewest orders         10
# 22722019         Fewest orders         10
# 22722020         Fewest orders         10
# 22722021         Fewest orders         10
# 22722022         Fewest orders         10
# 24054778        Average orders         10
# 24054779        Average orders         10
# 24054780        Average orders         10
# 24054781        Average orders         10
# 24054782        Average orders         10
# 24159284        Average orders         10
# 24159285        Average orders         10
# 24159286        Average orders         10
# 24159287        Average orders         10
# 24159288        Average orders         10
# 24159289        Average orders         10
# 24159290        Average orders         10
# 24159291        Average orders         10
# 24159292        Average orders         10
# 29447947           Most orders         10
# 29447948           Most orders         10
# 29447949           Most orders         10
# 29447950           Most orders         10
# 29447951           Most orders         10
# 29447952           Most orders         10
# 31897905         Fewest orders         10
# 31897906         Fewest orders         10
# 31897907         Fewest orders         10
# 31897908         Fewest orders         10

# %%
# Set your loc function

ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
# Check head with selected columns

ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0    202279      New customer             3
# 1    202279      New customer             3
# 2    202279      New customer             3
# 3    202279      New customer             3
# 4    202279      New customer             3
# 5    202279      New customer             3
# 6    202279      New customer             3
# 7    202279      New customer             3
# 8    202279      New customer             3
# 9    205970  Regular customer            16
# 10   205970  Regular customer            16
# 11   205970  Regular customer            16
# 12   205970  Regular customer            16
# 13   205970  Regular customer            16
# 14   205970  Regular customer            16
# 15   205970  Regular customer            16
# 16   205970  Regular customer            16
# 17   178520    Loyal customer            36
# 18   178520    Loyal customer            36
# 19   178520    Loyal customer            36
# 20   178520    Loyal customer            36
# 21   178520    Loyal customer            36
# 22   178520    Loyal customer            36
# 23   178520    Loyal customer            36
# 24   178520    Loyal customer            36
# 25   178520    Loyal customer            36
# 26   178520    Loyal customer            36
# 27   178520    Loyal customer            36
# 28   178520    Loyal customer            36
# 29   178520    Loyal customer            36
# 30   156122    Loyal customer            42
# 31   156122    Loyal customer            42
# 32   156122    Loyal customer            42
# 33   156122    Loyal customer            42
# 34   156122    Loyal customer            42
# 35   156122    Loyal customer            42
# 36   156122    Loyal customer            42
# 37   156122    Loyal customer            42
# 38   156122    Loyal customer            42
# 39   156122    Loyal customer            42
# 40   156122    Loyal customer            42
# 41   156122    Loyal customer            42
# 42   156122    Loyal customer            42
# 43   156122    Loyal customer            42
# 44   156122    Loyal customer            42
# 45   156122    Loyal customer            42
# 46   156122    Loyal customer            42
# 47   156122    Loyal customer            42
# 48   156122    Loyal customer            42
# 49   156122    Loyal customer            42
# 50   156122    Loyal customer            42
# 51   156122    Loyal customer            42
# 52   156122    Loyal customer            42
# 53   156122    Loyal customer            42
# 54   156122    Loyal customer            42
# 55   156122    Loyal customer            42
# 56    22352      New customer             4
# 57    22352      New customer             4
# 58    22352      New customer             4
# 59   142903  Regular customer            11
